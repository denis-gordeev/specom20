# %%
# %%writefile setup.sh
#
# git clone https://github.com/NVIDIA/apex
# cd apex
# pip install -v --no-cache-dir ./
# Out:
# Writing setup.sh

# %%
# !pip install transformers
# !pip install seqeval
# !sh setup.sh
# Out:
# ...
#      |████████████████████████████████| 675kB 7.7MB/s
# ...
#      |████████████████████████████████| 890kB 24.5MB/s
# ...
#      |████████████████████████████████| 3.8MB 45.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 55.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=cb11952bb941786c010dddbc299f9a53e0ceabec6c495437211b4fb56090a8f3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#   Created wheel for seqeval: filename=seqeval-0.0.12-cp36-none-any.whl size=7424 sha256=ffc3e3a460b87b957c263836e84ced5be381aa609639e8d6a6bc6ca850963b22
#   Stored in directory: /root/.cache/pip/wheels/4f/32/0a/df3b340a82583566975377d65e724895b3fad101a3fb729f68
# Successfully built seqeval
# ...
# Cloning into 'apex'...
# remote: Enumerating objects: 7255, done.
# remote: Total 7255 (delta 0), reused 0 (delta 0), pack-reused 7255
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/kaggle_* ./
# !cp /content/drive/My\ Drive/trained-model-panic.zip ./
# !unzip trained-model-panic.zip
# Out:
# Archive:  trained-model-panic.zip
#    creating: trained-model/
#   inflating: trained-model/vocab.txt
#   inflating: trained-model/eval_results.txt
#  extracting: trained-model/tokenizer_config.json
#   inflating: trained-model/pytorch_model.bin
#   inflating: trained-model/special_tokens_map.json
#    creating: trained-model/checkpoint-2500/
#   inflating: trained-model/checkpoint-2500/vocab.txt
#  extracting: trained-model/checkpoint-2500/tokenizer_config.json
#   inflating: trained-model/checkpoint-2500/pytorch_model.bin
#   inflating: trained-model/checkpoint-2500/optimizer.pt
#   inflating: trained-model/checkpoint-2500/special_tokens_map.json
#   inflating: trained-model/checkpoint-2500/scheduler.pt
#   inflating: trained-model/checkpoint-2500/training_args.bin
#   inflating: trained-model/checkpoint-2500/config.json
#   inflating: trained-model/training_args.bin
#   inflating: trained-model/test_predictions_a.txt
#   inflating: trained-model/config.json

# %%
# !python run_classification.py \
#     --data_dir ./ \
#     --model_type bert \
#     --model_name_or_path bert-base-multilingual-uncased \
#     --task_name panic \
#     --output_dir trained-model \
#     --max_seq_length 128 \
#     --do_train \
#     --do_eval \
#     --evaluate_during_training \
#     --per_gpu_train_batch_size 96 \
#     --per_gpu_eval_batch_size 96 \
#     --num_train_epochs 2 \
#     --fp16 \
#     --overwrite_output_dir

# %%
# !zip -r trained-model.zip ./trained-model
# !cp ./trained-model.zip ./drive/My\ Drive/trained-model-panic.zip

# %%
# !tail kaggle_shortened_binary_test.csv
# !cp kaggle_shortened_binary_test.csv kaggle_shortened_binary_test_real.csv
# !mv kaggle_shortened_binary_test_4chan.csv kaggle_shortened_binary_test.csv
# !tail kaggle_shortened_binary_test.csv
# Out:
# "Shill out, man.",1.0
# "Alright, I'm gonna quote a white guy, because I know it's necessary for some of you.
#
# ""Colonies are the outhouses of the European soul, where a fellow can let his pants down and relax, enjoy the smell of his own shit.""
# -Thomas Pynchon
#
# The neighborhood we knew is gone, so you guys are gonna do what you want. Have fun wallowing in your own shit.",1.0
# "You can always hold your nose and vote for Hillary like many Democrats, who, in so doing, put their stamp of approval on her womanizing husband.",0.0
# Someone has to save America from socialist liberals ate up with the dumb ass.,1.0
# I left OC back in 1968.  Up till then OC was mostly farmland.  When they started pouring the cement I left.  Now?  A town I've lived in since 1971 is gone.  I am so sick w/ the total destruction of this town/state.  I'm so grateful I'm old and can just shut the door to all of the OC mindset.  Thanks Jim,0.0
# ...

# %%
# !python run_classification.py \
    --data_dir ./ \
    --model_type bert \
    --model_name_or_path bert-base-multilingual-uncased \
    --task_name panic \
    --output_dir trained-model \
    --max_seq_length 128 \
    --do_predict \
    --per_gpu_train_batch_size 96 \
    --per_gpu_eval_batch_size 96 \
    --num_train_epochs 2 \
    --fp16 \
    --overwrite_output_dir
# Out:
# 2020-06-14 22:31:56.571759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 06/14/2020 22:31:58 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# 06/14/2020 22:31:58 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-multilingual-uncased-config.json from cache at /root/.cache/torch/transformers/33b56ce0f312e47e4d77a57791a4fc6233ae4a560dd2bdd186107058294e58ab.fcb1786f49c279f0e0f158c9972b9bd9f6c0edb5d893dcb9b530d714d86f0edc
# 06/14/2020 22:31:58 - INFO - transformers.configuration_utils -   Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "finetuning_task": "panic",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
# ...
